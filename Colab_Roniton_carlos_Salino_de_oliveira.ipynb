# %% [markdown]
# estou achando a atividade um pouco complicada mas interessante pois estou aprendendo a analizar e manipular dados usando phyton

# %%
 #faz upload do arquivo exel
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-99e549fe-6b0e-4e00-900c-c4eb5d8096d3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-99e549fe-6b0e-4e00-900c-c4eb5d8096d3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#importar bibliteca pandas
import pandas as pd

# %%
#executa o arquivo
df = pd.read_excel('/content/default_of_credit_card_clients__courseware_version_1_21_19.xls')

# %%
#abre o arquivo
df.head()
# Out:
#               ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE PAY_1  PAY_2  \
# 0  798fc410-45c1      20000    2          2         1   24     2      2
# 1  8a8c8f3b-8eb4     120000    2          2         2   26    -1      2
# 2  85698822-43f5      90000    2          2         2   34     0      0
# 3  0737c11b-be42      50000    2          2         1   37     0      0
# 4  3b7f77cc-dbc0      50000    1          2         1   57    -1      0
#
#    PAY_3  PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 0     -1     -1  ...          0          0          0         0       689
# 1      0      0  ...       3272       3455       3261         0      1000
# 2      0      0  ...      14331      14948      15549      1518      1500
# 3      0      0  ...      28314      28959      29547      2000      2019
# 4     -1      0  ...      20940      19146      19131      2000     36681
#
#    PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
# identificar o  número de colunas no documento
n_colunas = df.shape[1]
print(f'O conjunto de dados possui {n_colunas} colunas.')
# Out:
# O conjunto de dados possui 25 colunas.

# %%
# determina número de linhas
n_linhas = df.shape[0]
print(f'O conjunto de dados possui {n_linhas} linhas (amostras).')
# Out:
# O conjunto de dados possui 30000 linhas (amostras).

# %%
# quais os  tipos de dados das colunas
tipos_de_dados = df.dtypes
print(tipos_de_dados)
# Out:
# ID                            object
# LIMIT_BAL                      int64
# SEX                            int64
# EDUCATION                      int64
# MARRIAGE                       int64
# AGE                            int64
# PAY_1                         object
# PAY_2                          int64
# PAY_3                          int64
# PAY_4                          int64
# PAY_5                          int64
# PAY_6                          int64
# BILL_AMT1                      int64
# BILL_AMT2                      int64
# BILL_AMT3                      int64
# BILL_AMT4                      int64
# BILL_AMT5                      int64
# BILL_AMT6                      int64
# PAY_AMT1                       int64
# PAY_AMT2                       int64
# PAY_AMT3                       int64
# PAY_AMT4                       int64
# PAY_AMT5                       int64
# PAY_AMT6                       int64
# default payment next month     int64
# dtype: object

# %%
# identificar das colunas numéricas categoricas
colunas_numericas = df.select_dtypes(include=['number']).columns
print(resumo_numerico)
# Out:
#             LIMIT_BAL           SEX     EDUCATION      MARRIAGE           AGE  \
# count    30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean    165760.989333      1.586500      1.833333      1.535900     35.108800
# std     130158.590432      0.513348      0.807699      0.542698      9.851592
# min          0.000000      0.000000      0.000000      0.000000      0.000000
# 25%      50000.000000      1.000000      1.000000      1.000000     28.000000
# 50%     140000.000000      2.000000      2.000000      2.000000     34.000000
# 75%     240000.000000      2.000000      2.000000      2.000000     41.000000
# max    1000000.000000      2.000000      6.000000      3.000000     79.000000
#
#               PAY_2         PAY_3         PAY_4         PAY_5         PAY_6  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      -0.132867     -0.164333     -0.219300     -0.263900     -0.288033
# ...

# %%
for coluna in colunas_numericas:
    print(f"Frequência da coluna {coluna}:")
# Out:
# Frequência da coluna LIMIT_BAL:
# Frequência da coluna SEX:
# Frequência da coluna EDUCATION:
# Frequência da coluna MARRIAGE:
# Frequência da coluna AGE:
# Frequência da coluna PAY_2:
# Frequência da coluna PAY_3:
# Frequência da coluna PAY_4:
# Frequência da coluna PAY_5:
# Frequência da coluna PAY_6:
# Frequência da coluna BILL_AMT1:
# Frequência da coluna BILL_AMT2:
# Frequência da coluna BILL_AMT3:
# Frequência da coluna BILL_AMT4:
# Frequência da coluna BILL_AMT5:
# Frequência da coluna BILL_AMT6:
# Frequência da coluna PAY_AMT1:
# Frequência da coluna PAY_AMT2:
# Frequência da coluna PAY_AMT3:
# Frequência da coluna PAY_AMT4:
# Frequência da coluna PAY_AMT5:
# Frequência da coluna PAY_AMT6:
# Frequência da coluna default payment next month:

# %%
# identificar colunas  categórica
colunas_categoricas = df.select_dtypes(include=['object']).columns
print(colunas_categoricas)
# Out:
# Index(['ID', 'PAY_1'], dtype='object')

# %%
# exibe a frequencia das colunas categoricas
for coluna in colunas_categoricas:
    print(f"Frequência da coluna {coluna}:")
# Out:
# Frequência da coluna ID:
# Frequência da coluna PAY_1:

# %%
print("Dados faltando em cada coluna:")
print(df.isnull().sum())
# Out:
# Dados faltando em cada coluna:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_1                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default payment next month    0
# dtype: int64

# %%
# !git clone https://github.com/seu-usuario/seu-repositorio.git
# Out:
# Cloning into 'seu-repositorio'...
# fatal: could not read Username for 'https://github.com': No such device or address
