# %% [markdown]
# <a href="https://colab.research.google.com/github/ronitoncarlos/Atividade-1-ciencia-de-dados-para-tomada-de-decisoes/blob/main/Conhe%C3%A7a_o_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Trabalho relacionado a atividade 2 disciplina ciencia de dados para tomadas de decisoes   Aluno roniton carlos salino de oliveira "MATRÍCULA
# 2563229"

# %% [markdown]
# **Reasoning**:
# Import pandas and load the dataset, then display the first 5 rows and the shape of the DataFrame.

# %%
import pandas as pd


df = pd.read_excel('default_of_credit_card_clients__courseware_version_1_21_19.xls')


display(df.head())


print(df.shape)
# Out:
#               ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE PAY_1  PAY_2  \
# 0  798fc410-45c1      20000    2          2         1   24     2      2
# 1  8a8c8f3b-8eb4     120000    2          2         2   26    -1      2
# 2  85698822-43f5      90000    2          2         2   34     0      0
# 3  0737c11b-be42      50000    2          2         1   37     0      0
# 4  3b7f77cc-dbc0      50000    1          2         1   57    -1      0
#
#    PAY_3  PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 0     -1     -1  ...          0          0          0         0       689
# 1      0      0  ...       3272       3455       3261         0      1000
# 2      0      0  ...      14331      14948      15549      1518      1500
# 3      0      0  ...      28314      28959      29547      2000      2019
# 4     -1      0  ...      20940      19146      19131      2000     36681
#
#    PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

def log_transform(x):


  if x > 0:
    return np.log(x)
  else:
    return 0

# %%
financial_features = ['BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6']
log_transformed_data = financial_data[financial_features].applymap(log_transform)
# Out:
# <ipython-input-18-ef8227385e3e>:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   log_transformed_data = financial_data[financial_features].applymap(log_transform)

# %%
for feature in financial_features:
  plt.figure(figsize=(8, 6))  # Define o tamanho da figura
  plt.hist(log_transformed_data[feature], bins=20)  # Cria o histograma
  plt.title(f'Histograma de {feature} (Transformação Logarítmica)')  # Define o título
  plt.xlabel(feature)  # Define o rótulo do eixo x
  plt.ylabel('Frequência')  # Define o rótulo do eixo y
  plt.show()  # Exibe o histograma

# %% [markdown]
# Exercício 1 (2,0pts): Crie listas com nomes para as características financeiras restantes.

# %%
# Características financeiras já utilizadas
financial_features = ['BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6']

# Características demográficas
demographic_features = ['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE']

# pagamento
#  representam o histórico de pagamentos)
payment_history_features = ['PAY_0', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6']

# Feature alvo
target_feature = ['default payment next month']

# Todas as features
all_features = demographic_features + payment_history_features + financial_features + target_feature

#  listas para verificação
print("Características demográficas:", demographic_features)
print("Histórico de pagamentos:", payment_history_features)
print("Feature alvo:", target_feature)
print("Todas as features:", all_features)
# Out:
# Características demográficas: ['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE']
# Histórico de pagamentos: ['PAY_0', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6']
# Feature alvo: ['default payment next month']
# Todas as features: ['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6', 'default payment next month']

# %% [markdown]
# Exercício 3 (4,0pts): Visualize as características de valor da fatura usando uma grade 2 por 3 de plotagens de histograma. Dica: Você pode usar 20 bins para essa visualização.

# %%
#  valor da fatura
bill_features = ['BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6']

# Cria uma grade de subplots 2x3
fig, axes = plt.subplots(2, 3, figsize=(15, 10))  # Ajuste para facil visualização


for i, feature in enumerate(bill_features):
    row = i // 3  # Calcula a linha
    col = i % 3   # Calcula a coluna
    axes[row, col].hist(df[feature], bins=20)

# %% [markdown]
# Exercício 4 (4,0pts): Obtenha o resumo de .describe() para as características de valor do pagamento. Faz sentido?

# %%
# Características de valor do pagamento
payment_features = ['PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6']

#  resumo estatístico
payment_summary = df[payment_features].describe()

# Exibi o resumo
print(payment_summary)
# Out:
#             PAY_AMT1      PAY_AMT2       PAY_AMT3       PAY_AMT4  \
# count   30000.000000  3.000000e+04   30000.000000   30000.000000
# mean     5613.321500  5.855410e+03    5174.387967    4776.089733
# std     16539.094312  2.299256e+04   17565.538305   15532.893047
# min         0.000000  0.000000e+00       0.000000       0.000000
# 25%       836.000000  7.217500e+02     371.000000     223.000000
# 50%      2084.500000  2.000000e+03    1776.000000    1500.000000
# 75%      5000.000000  5.000000e+03    4500.000000    4000.000000
# max    873552.000000  1.684259e+06  896040.000000  621000.000000
#
#             PAY_AMT5       PAY_AMT6
# count   30000.000000   30000.000000
# mean     4754.749200    5164.223267
# std     15239.070708   17712.664703
# min         0.000000       0.000000
# 25%       170.750000       9.000000
# 50%      1500.000000    1500.000000
# 75%      4000.000000    4000.000000
# max    426529.000000  528666.000000

# %% [markdown]
# xercício 5 (4,0pts): Plote um histograma das características de pagamento da fatura semelhante ao das características de valor da fatura, mas aplique também alguma rotação aos rótulos do eixo x com o argumento de palavra-chave xrot para que eles não se sobreponham. Podemos incluir o argumento de palavra-chave xrot=<ângulo> em qualquer função de plotagem para girar os rótulos do eixo x de acordo com um ângulo específico em graus. Considere os resultados.

# %%
# Características de pagamento da fatura
payment_features = ['PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6']

# Criar a grade de subplots 2x3
fig, axes = plt.subplots(2, 3, figsize=(15, 10))

# Iterar pelas features e plotar os histogramas com rotação dos rótulos do eixo x
for i, feature in enumerate(payment_features):
    row = i // 3
    col = i % 3
    axes[row, col].hist(df[feature], bins=20)
    axes[row, col].set_title(f'Histograma de {feature}')
    axes[row, col].set_xlabel(feature)
    axes[row, col].set_ylabel('Frequência')

    # Rotacionar os rótulos do eixo x em 45 graus
    plt.setp(axes[row, col].get_xticklabels(), rotation=45, ha='right')

# Ajustar o layout e exibir os plots
plt.tight_layout()
plt.show()

# %% [markdown]
# Exercício 6 (4,0pts): Use uma máscara booleana para ver quantos dos dados de valor do pagamento são exatamente iguais a 0. O resultado faz sentido dado o histograma da etapa anterior?

# %%
# Características de valor do pagamento
payment_features = ['PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6']

# Criar a máscara booleana para valores iguais a 0
zero_payment_mask = df[payment_features] == 0

# Contar o número de valores True em cada coluna (valores iguais a 0)
zero_payment_counts = zero_payment_mask.sum()

# Exibir os resultados
print(zero_payment_counts)
# Out:
# PAY_AMT1    5504
# PAY_AMT2    5663
# PAY_AMT3    6223
# PAY_AMT4    6660
# PAY_AMT5    6955
# PAY_AMT6    7416
# dtype: int64

# %% [markdown]
# Exercício 7 (4,0pts): Ignorando os pagamentos iguais a 0 usando a máscara que criou na etapa anterior, utilize o método .apply() do pandas e o método np.log10() do NumPy para plotar histogramas de transformações logarítmicas dos pagamentos diferentes de zero. Considere os resultados. Dica: Você pode usar .apply() para aplicar qualquer função, inclusive log10, a todos os elementos de um DataFrame ou de uma coluna usando a sintaxe a seguir: .apply(<nome_função>).

# %%
# Características de valor do pagamento
payment_features = ['PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6']

# Criar a máscara booleana para valores iguais a 0
zero_payment_mask = df[payment_features] == 0

# Criar um novo DataFrame com os pagamentos diferentes de zero
nonzero_payments = df[payment_features][~zero_payment_mask]

# Aplicar a transformação logarítmica usando .apply() e np.log10()
log_transformed_payments = nonzero_payments.apply(np.log10)

# Plotar os histogramas
fig, axes = plt.subplots(2, 3, figsize=(15, 10))

for i, feature in enumerate(payment_features):
    row = i // 3
    col = i % 3
    axes[row, col].hist(log_transformed_payments[feature].dropna(), bins=20)  # dropna() para remover NaNs
    axes[row, col].set_title(f'Histograma de {feature} (log10)')
    axes[row, col].set_xlabel(feature)
    axes[row, col].set_ylabel('Frequência')

plt.tight_layout()
plt.show()
